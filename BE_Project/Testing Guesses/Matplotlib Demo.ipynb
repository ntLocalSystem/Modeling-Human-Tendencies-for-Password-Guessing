# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import os
from matplotlib import pyplot as plt
from scipy.interpolate import make_interp_spline, BSpline
# %matplotlib inline

# %%
gru_1_path = os.path.join("P:\\BE_Project", "Testing Guesses", "GRU Password Guessing", "Post Processing Scripts", "result_test.csv")
lstm_1_path = os.path.join("P:\\BE_Project", "Testing Guesses", "LSTM Password Guessing - postprocessed - Copy", "Post Processing Scripts", "result_test.csv")

# %%
gru_1_df = pd.read_csv(gru_1_path)
lstm_1_df = pd.read_csv(lstm_1_path)

# %%
gru_1_df.columns
# Out:
# Index(['Guesses', 'one_to_eight', 'nine_to_fifteen', 'sixteen_to_thirtytwo'], dtype='object')

# %%
total8 = 2250012
total15 = 1345062
total32 = 70738
guesses_num_gru = np.array(gru_1_df["Guesses"])
guesses_num_lstm = np.array(lstm_1_df["Guesses"])

gru8 = (np.array(gru_1_df["one_to_eight"])/total8)*100
lstm8 = (np.array(lstm_1_df["one_to_eight"])/total8)*100

gru15 = (np.array(gru_1_df["nine_to_fifteen"])/total15)*100
lstm15 = (np.array(lstm_1_df["nine_to_fifteen"])/total15)*100

gru32 = (np.array(gru_1_df["sixteen_to_thirtytwo"])/total32)*100
lstm32 = (np.array(lstm_1_df["sixteen_to_thirtytwo"])/total32)*100


plt.figure(1)


fig.suptitle("Cracking Performance of LSTM and GRU", fontsize=16)

ax1 = plt.subplot(131)
ax1.set_title("1-8")
plt.xlabel("Number of Guesses")
plt.ylabel("Percent Guessed")
axes = plt.gca()
axes.set_ylim([0.0, 100.0])


# plt.subplot(132)

# plt.xlabel("Number of Guesses")
# plt.ylabel("Percent Guessed")
# #axes = plt.gca()
# #axes.set_ylim([0.0, 100.0])

# spl1 = make_interp_spline(guesses_num_lstm, lstm8, k=3)
# lstm8_smooth = spl1(guesses_num_new_lstm)


#create smooth line chart 
plt.plot(guesses_num_gru, gru8, "m-", label = "GRU")
plt.plot(guesses_num_lstm, lstm8, "c-", label = "LSTM")
plt.legend(loc = "best")




ax2 = plt.subplot(132)
ax2.set_title("9-15")

plt.xlabel("Number of Guesses")
plt.ylabel("Percent Guessed")
axes = plt.gca()
axes.set_ylim([0.0, 100.0])


# plt.subplot(132)

# plt.xlabel("Number of Guesses")
# plt.ylabel("Percent Guessed")
# #axes = plt.gca()
# #axes.set_ylim([0.0, 100.0])

# spl1 = make_interp_spline(guesses_num_lstm, lstm8, k=3)
# lstm8_smooth = spl1(guesses_num_new_lstm)


#create smooth line chart 
plt.plot(guesses_num_gru, gru15, "m-", label = "GRU")
plt.plot(guesses_num_lstm, lstm15, "c-", label = "LSTM")
plt.legend(loc = "best")



ax3 = plt.subplot(133)
ax3.set_title("16-32")

plt.xlabel("Number of Guesses")
plt.ylabel("Percent Guessed")
axes = plt.gca()
axes.set_ylim([0.0, 100.0])


# plt.subplot(132)

# plt.xlabel("Number of Guesses")
# plt.ylabel("Percent Guessed")
# #axes = plt.gca()
# #axes.set_ylim([0.0, 100.0])

# spl1 = make_interp_spline(guesses_num_lstm, lstm8, k=3)
# lstm8_smooth = spl1(guesses_num_new_lstm)


#create smooth line chart 
plt.plot(guesses_num_gru, gru32, "m-", label = "GRU")
plt.plot(guesses_num_lstm, lstm32, "c-", label = "LSTM")
plt.legend(loc = "best")

axes1[0].set_title = "Less than or equal to 8"


fig = plt.gcf()
fig.set_size_inches(18.5, 5.5)

# ----------------------------------------------- Fig 2 -----------------------------------------

plt.figure(2)
ax1 = plt.subplot(131)
ax1.set_title("1-8")

plt.xlabel("Number of Guesses")
plt.ylabel("Percent Guessed")
axes = plt.gca()
axes.set_ylim([0.0, 100.0])


# plt.subplot(132)

# plt.xlabel("Number of Guesses")
# plt.ylabel("Percent Guessed")
# #axes = plt.gca()
# #axes.set_ylim([0.0, 100.0])

# spl1 = make_interp_spline(guesses_num_lstm, lstm8, k=3)
# lstm8_smooth = spl1(guesses_num_new_lstm)


#create smooth line chart 
plt.plot(guesses_num_gru, gru8, "m-", label = "GRU")
plt.legend(loc = "best")




ax2 = plt.subplot(132)
ax2.set_title("9-15")

plt.xlabel("Number of Guesses")
plt.ylabel("Percent Guessed")
axes = plt.gca()
axes.set_ylim([0.0, 100.0])


# plt.subplot(132)

# plt.xlabel("Number of Guesses")
# plt.ylabel("Percent Guessed")
# #axes = plt.gca()
# #axes.set_ylim([0.0, 100.0])

# spl1 = make_interp_spline(guesses_num_lstm, lstm8, k=3)
# lstm8_smooth = spl1(guesses_num_new_lstm)


#create smooth line chart 
plt.plot(guesses_num_gru, gru15, "m-", label = "GRU")
plt.legend(loc = "best")




ax3 = plt.subplot(133)
ax3.set_title("16-32")

plt.xlabel("Number of Guesses")
plt.ylabel("Percent Guessed")
axes = plt.gca()
axes.set_ylim([0.0, 100.0])


# plt.subplot(132)

# plt.xlabel("Number of Guesses")
# plt.ylabel("Percent Guessed")
# #axes = plt.gca()
# #axes.set_ylim([0.0, 100.0])

# spl1 = make_interp_spline(guesses_num_lstm, lstm8, k=3)
# lstm8_smooth = spl1(guesses_num_new_lstm)


#create smooth line chart 
plt.plot(guesses_num_gru, gru32, "m-", label = "GRU")
plt.legend(loc = "best")


fig = plt.gcf()
fig.set_size_inches(18.5, 5.5)

# ------------------------------------------------- Fig 3 -----------------------------------------------------------
plt.figure(3)
ax1 = plt.subplot(131)
ax1.set_title("1-8")

plt.xlabel("Number of Guesses")
plt.ylabel("Percent Guessed")
axes = plt.gca()
axes.set_ylim([0.0, 100.0])


# plt.subplot(132)

# plt.xlabel("Number of Guesses")
# plt.ylabel("Percent Guessed")
# #axes = plt.gca()
# #axes.set_ylim([0.0, 100.0])

# spl1 = make_interp_spline(guesses_num_lstm, lstm8, k=3)
# lstm8_smooth = spl1(guesses_num_new_lstm)


#create smooth line chart 
plt.plot(guesses_num_lstm, lstm8, "c-", label = "LSTM")
plt.legend(loc = "best")




ax2 = plt.subplot(132)
ax2.set_title("9-15")

plt.xlabel("Number of Guesses")
plt.ylabel("Percent Guessed")
axes = plt.gca()
axes.set_ylim([0.0, 100.0])


# plt.subplot(132)

# plt.xlabel("Number of Guesses")
# plt.ylabel("Percent Guessed")
# #axes = plt.gca()
# #axes.set_ylim([0.0, 100.0])

# spl1 = make_interp_spline(guesses_num_lstm, lstm8, k=3)
# lstm8_smooth = spl1(guesses_num_new_lstm)


#create smooth line chart 
plt.plot(guesses_num_lstm, lstm15, "c-", label = "LSTM")
plt.legend(loc = "best")


ax3 = plt.subplot(133)
ax3.set_title("16-32")

plt.xlabel("Number of Guesses")
plt.ylabel("Percent Guessed")
axes = plt.gca()
axes.set_ylim([0.0, 100.0])


# plt.subplot(132)

# plt.xlabel("Number of Guesses")
# plt.ylabel("Percent Guessed")
# #axes = plt.gca()
# #axes.set_ylim([0.0, 100.0])

# spl1 = make_interp_spline(guesses_num_lstm, lstm8, k=3)
# lstm8_smooth = spl1(guesses_num_new_lstm)


#create smooth line chart 
plt.plot(guesses_num_lstm, lstm32, "c-", label = "LSTM")
plt.legend(loc = "best")


fig = plt.gcf()
fig.set_size_inches(18.5, 5.5)

# %%
gru32[-1]
# Out:
# 15.530549351126693

# %%
lstm32[-1]
# Out:
# 24.920127795527154
